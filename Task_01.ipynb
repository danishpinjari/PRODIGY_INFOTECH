# %%
import numpy as np 
import pandas as pd 
import os

# %%
train = pd.read_csv("train.csv")
test_df= pd.read_csv("test.csv")

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %%
missing_columns = train.columns[train.isna().any()].tolist()

for col in missing_columns:
    print(f"{col}\t{train[col].isnull().sum()}")
# Out:
# LotFrontage	259
# Alley	1369
# MasVnrType	872
# MasVnrArea	8
# BsmtQual	37
# BsmtCond	37
# BsmtExposure	38
# BsmtFinType1	37
# BsmtFinType2	38
# Electrical	1
# FireplaceQu	690
# GarageType	81
# GarageYrBlt	81
# GarageFinish	81
# GarageQual	81
# GarageCond	81
# PoolQC	1453
# Fence	1179
# MiscFeature	1406

# %%
train.drop(['MiscFeature','Fence','PoolQC','Alley'],axis=1,inplace=True)
train.MasVnrArea = train.MasVnrArea.fillna(train["LotFrontage"].mean())
train.GarageYrBlt = train.GarageYrBlt.fillna(train["LotFrontage"].mean())

# %%
train.GarageCond.value_counts()
# Out:
# GarageCond
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: count, dtype: int64

# %%
train.MasVnrType = train.MasVnrType.replace(np.NaN,"BrkFace")

# %%
train.BsmtQual = train.BsmtQual.replace(np.NaN,"TA")
train.BsmtCond = train.BsmtCond.replace(np.NaN,"TA")
train.BsmtExposure = train.BsmtExposure.replace(np.NaN,"No")
train.BsmtFinType2 = train.BsmtFinType2.replace(np.NaN,"Unf")
train.FireplaceQu = train.FireplaceQu.replace(np.NaN,"Gd")
train.GarageType = train.GarageType.replace(np.NaN,"Attchd ")
train.GarageFinish = train.GarageFinish.replace(np.NaN,"Unf")
train.GarageQual = train.GarageQual.replace(np.NaN,"TA")
train.GarageCond = train.GarageCond.replace(np.NaN,"TA")

# %%
train.drop('Electrical',axis=1,inplace=True)

# %%
train.BsmtQual,_ = pd.factorize(train.BsmtQual)
train.BsmtCond,_ = pd.factorize(train.BsmtCond)
train.BsmtExposure,_ = pd.factorize(train.BsmtExposure)
train.BsmtFinType2,_ = pd.factorize(train.BsmtFinType2)
train.GarageType,_ = pd.factorize(train.GarageType)
train.GarageFinish,_ = pd.factorize(train.GarageFinish)
train.GarageQual,_ = pd.factorize(train.GarageQual)
train.GarageCond,_ = pd.factorize(train.GarageCond)
train.FireplaceQu,_ = pd.factorize(train.FireplaceQu)
train.MasVnrType,_ = pd.factorize(train.MasVnrType)
train.Street,_ = pd.factorize(train.Street)
train.LotShape,_ = pd.factorize(train.LotShape)
train.LandContour,_ = pd.factorize(train.LandContour)
train.Utilities,_ = pd.factorize(train.Utilities)
train.LandSlope,_ = pd.factorize(train.LandSlope)
train.Neighborhood,_ = pd.factorize(train.Neighborhood)
train.Condition1,_ = pd.factorize(train.Condition1)
train.Condition2,_ = pd.factorize(train.Condition2)
train.BldgType,_ = pd.factorize(train.BldgType)
train.HouseStyle,_ = pd.factorize(train.HouseStyle)
train.RoofStyle,_ = pd.factorize(train.RoofStyle)
train.RoofMatl,_ = pd.factorize(train.RoofMatl)
train.Exterior1st,_ = pd.factorize(train.Exterior1st)
train.Exterior2nd,_ = pd.factorize(train.Exterior2nd)
train.MasVnrType,_ = pd.factorize(train.MasVnrType)

# %%
train.LotFrontage,_ = pd.factorize(train.LotFrontage)
train.LotConfig,_ = pd.factorize(train.LotConfig)
train.BsmtFinType1,_ = pd.factorize(train.BsmtFinType1)
train.Heating,_ = pd.factorize(train.Heating)
train.HeatingQC,_ = pd.factorize(train.HeatingQC)
train.CentralAir,_ = pd.factorize(train.CentralAir)
train.KitchenQual,_ = pd.factorize(train.KitchenQual)
train.Functional,_ = pd.factorize(train.GarageCond)
train.PavedDrive,_ = pd.factorize(train.PavedDrive)
train.SaleCondition,_ = pd.factorize(train.SaleCondition)
train.SaleType,_ = pd.factorize(train.SaleType)

# %%
train.MSZoning,_ = pd.factorize(train.MSZoning)
train.ExterQual,_ = pd.factorize(train.ExterQual)
train.ExterCond,_ = pd.factorize(train.ExterCond)
train.Foundation,_ = pd.factorize(train.Foundation)

# %%
missing_columns = train.columns[train.isna().any()].tolist()

for col in missing_columns:
    print(f"{col}\t{train[col].isnull().sum()}\t{train[col].dtype}")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   LotShape       1460 non-null   int64
#  7   LandContour    1460 non-null   int64
#  8   Utilities      1460 non-null   int64
#  9   LotConfig      1460 non-null   int64
#  10  LandSlope      1460 non-null   int64
#  11  Neighborhood   1460 non-null   int64
#  12  Condition1     1460 non-null   int64
#  13  Condition2     1460 non-null   int64
#  14  BldgType       1460 non-null   int64
#  15  HouseStyle     1460 non-null   int64
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
# ...

# %%
X = train.iloc[:,1:-1]
y = train['SalePrice']
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   int64
#  2   LotFrontage    1460 non-null   int64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   int64
#  5   LotShape       1460 non-null   int64
#  6   LandContour    1460 non-null   int64
#  7   Utilities      1460 non-null   int64
#  8   LotConfig      1460 non-null   int64
#  9   LandSlope      1460 non-null   int64
#  10  Neighborhood   1460 non-null   int64
#  11  Condition1     1460 non-null   int64
#  12  Condition2     1460 non-null   int64
#  13  BldgType       1460 non-null   int64
#  14  HouseStyle     1460 non-null   int64
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
#  17  YearBuilt      1460 non-null   int64
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from catboost import CatBoostRegressor
catboost_model = CatBoostRegressor(iterations=500, depth=10, learning_rate=0.05, loss_function='RMSE', random_seed=42)

# %%
catboost_model.fit(X_train, y_train, cat_features=[])
# Out:
# 0:	learn: 75756.3516668	total: 201ms	remaining: 1m 40s
# 1:	learn: 73422.7143217	total: 254ms	remaining: 1m 3s
# 2:	learn: 71195.5105839	total: 305ms	remaining: 50.6s
# 3:	learn: 69460.0434059	total: 359ms	remaining: 44.6s
# 4:	learn: 67560.1181672	total: 420ms	remaining: 41.6s
# 5:	learn: 65979.4351170	total: 470ms	remaining: 38.7s
# 6:	learn: 64154.4744791	total: 521ms	remaining: 36.7s
# 7:	learn: 62498.7383441	total: 567ms	remaining: 34.9s
# 8:	learn: 60857.2415546	total: 614ms	remaining: 33.5s
# 9:	learn: 59452.1661164	total: 660ms	remaining: 32.4s
# 10:	learn: 57963.0251967	total: 708ms	remaining: 31.5s
# 11:	learn: 56495.7657971	total: 756ms	remaining: 30.7s
# 12:	learn: 55181.5079866	total: 801ms	remaining: 30s
# 13:	learn: 53849.7879989	total: 847ms	remaining: 29.4s
# 14:	learn: 52449.8274027	total: 892ms	remaining: 28.8s
# 15:	learn: 51225.4381428	total: 942ms	remaining: 28.5s
# 16:	learn: 49955.1330061	total: 988ms	remaining: 28.1s
# ...

# %%
y_pred = catboost_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 30526.042976864526

# %%
test_df.drop(['MiscFeature','Fence','PoolQC','Alley','Electrical'],axis=1,inplace=True)
test_df.MasVnrArea = test_df.MasVnrArea.fillna(test_df["MasVnrArea"].mean())
test_df.GarageYrBlt = test_df.GarageYrBlt.fillna(test_df["GarageYrBlt"].mean())
test_df.BsmtFinSF1 = test_df.BsmtFinSF1.fillna(test_df["BsmtFinSF1"].mean())
test_df.BsmtFinSF2 = test_df.BsmtFinSF2.fillna(test_df["BsmtFinSF2"].mean())
test_df.BsmtUnfSF = test_df.BsmtUnfSF.fillna(test_df["BsmtUnfSF"].mean())
test_df.BsmtFullBath = test_df.BsmtFullBath.fillna(test_df["BsmtFullBath"].mean())
test_df.GarageCars = test_df.GarageCars.fillna(test_df["GarageCars"].mean())
test_df.GarageArea = test_df.GarageArea.fillna(test_df["GarageArea"].mean())
test_df.TotalBsmtSF = test_df.TotalBsmtSF.fillna(test_df["TotalBsmtSF"].mean())

# %%
test_df.BsmtHalfBath = test_df.BsmtHalfBath.fillna(test_df["BsmtHalfBath"].mean())

# %%
test_df.MasVnrType = test_df.MasVnrType.replace(np.NaN,"BrkFace")
test_df.BsmtQual = test_df.BsmtQual.replace(np.NaN,"TA")
test_df.BsmtCond = test_df.BsmtCond.replace(np.NaN,"TA")
test_df.BsmtExposure = test_df.BsmtExposure.replace(np.NaN,"No")
test_df.BsmtFinType2 = test_df.BsmtFinType2.replace(np.NaN,"Unf")
test_df.FireplaceQu = test_df.FireplaceQu.replace(np.NaN,"Gd")
test_df.GarageType = test_df.GarageType.replace(np.NaN,"Attchd ")
test_df.GarageFinish = test_df.GarageFinish.replace(np.NaN,"Unf")
test_df.GarageQual = test_df.GarageQual.replace(np.NaN,"TA")
test_df.GarageCond = test_df.GarageCond.replace(np.NaN,"TA")
test_df.BsmtQual,_ = pd.factorize(test_df.BsmtQual)
test_df.BsmtCond,_ = pd.factorize(test_df.BsmtCond)
test_df.BsmtExposure,_ = pd.factorize(test_df.BsmtExposure)
test_df.BsmtFinType2,_ = pd.factorize(test_df.BsmtFinType2)
test_df.GarageType,_ = pd.factorize(test_df.GarageType)
test_df.GarageFinish,_ = pd.factorize(test_df.GarageFinish)
test_df.GarageQual,_ = pd.factorize(test_df.GarageQual)
test_df.GarageCond,_ = pd.factorize(test_df.GarageCond)
test_df.FireplaceQu,_ = pd.factorize(test_df.FireplaceQu)
test_df.MasVnrType,_ = pd.factorize(test_df.MasVnrType)
test_df.Street,_ = pd.factorize(test_df.Street)
test_df.LotShape,_ = pd.factorize(test_df.LotShape)
test_df.LandContour,_ = pd.factorize(test_df.LandContour)
test_df.Utilities,_ = pd.factorize(test_df.Utilities)
test_df.LandSlope,_ = pd.factorize(test_df.LandSlope)
test_df.Neighborhood,_ = pd.factorize(test_df.Neighborhood)
test_df.Condition1,_ = pd.factorize(test_df.Condition1)
test_df.Condition2,_ = pd.factorize(test_df.Condition2)
test_df.BldgType,_ = pd.factorize(test_df.BldgType)
test_df.HouseStyle,_ = pd.factorize(test_df.HouseStyle)
test_df.RoofStyle,_ = pd.factorize(test_df.RoofStyle)
test_df.RoofMatl,_ = pd.factorize(test_df.RoofMatl)
test_df.Exterior1st,_ = pd.factorize(test_df.Exterior1st)
test_df.Exterior2nd,_ = pd.factorize(test_df.Exterior2nd)
test_df.MasVnrType,_ = pd.factorize(test_df.MasVnrType)
test_df.LotFrontage,_ = pd.factorize(test_df.LotFrontage)
test_df.LotConfig,_ = pd.factorize(test_df.LotConfig)
test_df.BsmtFinType1,_ = pd.factorize(test_df.BsmtFinType1)
test_df.Heating,_ = pd.factorize(test_df.Heating)
test_df.HeatingQC,_ = pd.factorize(test_df.HeatingQC)
test_df.HeatingQC,_ = pd.factorize(test_df.HeatingQC)
test_df.CentralAir,_ = pd.factorize(test_df.CentralAir)
test_df.KitchenQual,_ = pd.factorize(test_df.KitchenQual)
test_df.Functional,_ = pd.factorize(test_df.GarageCond)
test_df.PavedDrive,_ = pd.factorize(test_df.PavedDrive)
test_df.SaleCondition,_ = pd.factorize(test_df.SaleCondition)
test_df.SaleType,_ = pd.factorize(test_df.SaleType)
test_df.MSZoning,_ = pd.factorize(test_df.MSZoning)
test_df.ExterQual,_ = pd.factorize(test_df.ExterQual)
test_df.ExterCond,_ = pd.factorize(test_df.ExterCond)
test_df.Foundation,_ = pd.factorize(test_df.Foundation)

# %%
y_pred1 = catboost_model.predict(test_df)

submission_path = 'sample_submission.csv'

submission = pd.read_csv(submission_path)

submission['SalePrice'] = y_pred1

submission.to_csv('submission.csv', index=False)

# %%
submission.head(20)
# Out:
#       Id      SalePrice
# 0   1461  143875.788189
# 1   1462  165219.982333
# 2   1463  176151.857230
# 3   1464  180045.130598
# 4   1465  197690.542834
# 5   1466  174666.768771
# 6   1467  165037.518679
# 7   1468  160512.499408
# 8   1469  175541.525070
# 9   1470  136891.834702
# 10  1471  192739.121074
# 11  1472  125074.380919
# 12  1473  123406.181806
# 13  1474  156717.798040
# 14  1475  137860.761385
# 15  1476  326597.936452
# 16  1477  239748.803839
# 17  1478  279134.481571
# 18  1479  299807.020733
# 19  1480  421285.655292
